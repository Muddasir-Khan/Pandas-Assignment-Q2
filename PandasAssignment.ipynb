# %% [markdown]
# # Part 1

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BC9B-4E79
#
#  Directory of C:\Users\User\Downloads\PIAIC-BATCH-35-Q2-main\PIAIC-BATCH-35-Q2-main\Assignment
#
# 03/03/2021  03:19 PM    <DIR>          .
# 03/03/2021  03:19 PM    <DIR>          ..
# 03/02/2021  09:04 AM    <DIR>          .ipynb_checkpoints
# 02/08/2021  11:18 AM             1,231 inventory.csv
# 03/03/2021  03:19 PM            47,219 PandasAssignment.ipynb
# 02/08/2021  11:18 AM             6,466 README.md
# 02/08/2021  11:18 AM             1,098 states0.csv
# 02/08/2021  11:18 AM             1,096 states1.csv
# 02/08/2021  11:18 AM             1,106 states2.csv
# 02/08/2021  11:18 AM             1,081 states3.csv
# 02/08/2021  11:18 AM             1,116 states4.csv
# 02/08/2021  11:18 AM             1,120 states5.csv
# 02/08/2021  11:18 AM             1,115 states6.csv
# 02/08/2021  11:18 AM             1,139 states7.csv
# 02/08/2021  11:18 AM             1,136 states8.csv
# ...

# %%
dfinventory = pd.read_csv('inventory.csv');
dfstate0 = pd.read_csv('states0.csv');
dfstate1 = pd.read_csv('states1.csv')

# %%
dfinventory
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
dfstate0
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
# 5           5    Colorado   5278906   20.78438003220608%   69.89557165861504%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
# ...

# %%
dfstate1
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
#
#                  White                Black                Native  \
# 0   69.89557165861504%   3.546376811594201%   0.5738325281803548%
# 1    67.6770531400966%   10.34806763285027%  0.12620772946859898%
# 2   64.63271028037383%  20.743925233644834%  0.25981308411214965%
# 3  33.103910614525134%   51.77653631284915%  0.20055865921787713%
# 4   59.08374880153398%  15.165675934803444%   0.2104506232023015%
# 5   54.28630556974962%   32.08829841594277%  0.18758303525804798%
#
# ...

# %%
import glob as gl
gl.glob('s*.csv')
# Out:
# ['states0.csv',
#  'states1.csv',
#  'states2.csv',
#  'states3.csv',
#  'states4.csv',
#  'states5.csv',
#  'states6.csv',
#  'states7.csv',
#  'states8.csv',
#  'states9.csv']

# %%
#Alternate method used initially 
#dfus_census = pd.DataFrame()
#for i in gl.glob('s*.csv'):
#    dfstatefile = pd.read_csv(i)
#    dfus_census = pd.concat([dfus_census, dfstatefile])

df_from_each_file = (pd.read_csv(f) for f in gl.glob('s*.csv'))
dfus_census   = pd.concat(df_from_each_file, ignore_index=True)

# %%
dfus_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
dfus_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
dfus_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
dfus_censuscln = dfus_census.copy()

# %%
dfus_censuscln.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
import re

# %%
#dfus_censuscln['Income'].replace(to_replace="\$([0-9,\.]+).*", value=r"\1", regex=True, inplace=True)
dfus_censuscln['Income'].replace(to_replace="\$([0-9,\.]+).*", value=r"\1", regex=True, inplace=True)

# %%
dfus_censuscln.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific             Income            GenderPop
# ...

# %%
dfus_censuscln[['MalePop', 'FemalePop']] =  dfus_censuscln.GenderPop.str.split(pat = '_', expand = True)

# %%
dfus_censuscln['Income'].replace(to_replace="\$([0-9,\.]+).*", value=r"\1", regex=True, inplace=True)

# %%
dfus_censuscln.MalePop.replace(to_replace="([0-9,\.]+)*\D", value=r"\1", regex=True, inplace=True);
dfus_censuscln['FemalePop'].replace(to_replace="([0-9,\.]+)*\D", value=r"\1", regex=True, inplace=True)

# %%
dfus_censuscln.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific             Income            GenderPop   MalePop  \
# ...

# %%
dfus_censuscln.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# MalePop       object
# FemalePop     object
# dtype: object

# %%
#Initial Method
#dfus_censuscln['Income'] = pd.to_numeric(dfus_censuscln['Income'])
#dfus_censuscln['MalePop'] = pd.to_numeric(dfus_censuscln['MalePop']);
#dfus_censuscln['FemalePop'] = pd.to_numeric(dfus_censuscln['FemalePop']);

cols = ['Income', 'MalePop', 'FemalePop']
dfus_censuscln[cols] = dfus_censuscln[cols].apply(pd.to_numeric, axis=1)

# %%
dfus_censuscln.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income        float64
# GenderPop      object
# MalePop       float64
# FemalePop     float64
# dtype: object

# %%
dfus_censuscln.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income            GenderPop     MalePop  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(dfus_censuscln.FemalePop, dfus_censuscln.Income);
plt.show()

# %%
(dfus_censuscln.isnull()).any()
# Out:
# Unnamed: 0    False
# State         False
# TotalPop      False
# Hispanic      False
# White         False
# Black         False
# Native        False
# Asian         False
# Pacific        True
# Income        False
# GenderPop     False
# MalePop       False
# FemalePop      True
# dtype: bool

# %%
dfus_censuscln.FemalePop.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# Name: FemalePop, dtype: bool

# %%
dfus_censuscln[dfus_censuscln.FemalePop.isnull()]
# Out:
#     Unnamed: 0     State  TotalPop             Hispanic               White  \
# 23           5  Maryland   5930538    8.47249820014399%    52.679049676026%
# 24           0  Maryland   5930538    8.47249820014399%    52.679049676026%
# 31           1   Montana   1014699  3.2688888888888896%  86.41555555555554%
#
#                   Black                Native                Asian  \
# 23    30.6777537796976%  0.20309575233981278%   5.325413966882652%
# 24    30.6777537796976%  0.20309575233981278%   5.325413966882652%
# 31  0.4292592592592591%   7.0607407407407425%  0.5703703703703705%
#
#                  Pacific        Income   GenderPop    MalePop  FemalePop
# 23  0.03628509719222463%  78765.400725  2872643M_F  2872643.0        NaN
# 24  0.03628509719222463%  78765.400725  2872643M_F  2872643.0        NaN
# 31  0.07222222222222222%  47645.682836   510163M_F   510163.0        NaN

# %%
dfus_censuscln.FemalePop.fillna(value = dfus_censuscln.TotalPop - dfus_censuscln.MalePop, inplace = True)

# %%
(dfus_censuscln.isnull()).any()
# Out:
# Unnamed: 0    False
# State         False
# TotalPop      False
# Hispanic      False
# White         False
# Black         False
# Native        False
# Asian         False
# Pacific        True
# Income        False
# GenderPop     False
# MalePop       False
# FemalePop     False
# dtype: bool

# %%
dfus_censuscln.FemalePop
# Out:
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334329.0
# 5      2630239.0
# 6      2630239.0
# 7      1841615.0
# 8       478041.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 19     1453125.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 23     3057895.0
# 24     3057895.0
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 31      504536.0
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 40      353677.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# ...

# %%
dfus_censuscln.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop', 'MalePop',
#        'FemalePop'],
#       dtype='object')

# %%
dfus_censuscln2 = dfus_censuscln.copy()

# %%
dfus_censuscln2.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
dfus_censuscln2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
dfus_censuscln2[dfus_censuscln2.duplicated()]
# Out:
#            State  TotalPop             Hispanic                White  \
# 6       Colorado   5278906   20.78438003220608%   69.89557165861504%
# 12       Georgia  10006693   8.418242207460397%   54.28630556974962%
# 18          Iowa   3093526    5.30364520048603%   87.71968408262464%
# 24      Maryland   5930538    8.47249820014399%     52.679049676026%
# 30      Missouri   6045448   4.037247838616718%     77.508069164265%
# 36    New Jersey   8904413   18.74950049950049%  56.488761238761285%
# 42          Ohio  11575977  3.6720843250595037%   75.90306018361096%
# 48  Rhode Island   1053661  13.356666666666678%   74.32541666666665%
# 54          Utah   2903379  13.468376068376063%   79.40683760683764%
#
#                   Black                Native                Asian  \
# 6    3.546376811594201%   0.5738325281803548%   2.661996779388082%
# 12   32.08829841594277%  0.18758303525804798%  3.0976494634644895%
# 18  3.2569866342648868%   0.2897934386391251%   1.699392466585662%
# ...

# %%
dfus_censuscln2.drop_duplicates(inplace = True)

# %%
dfus_censuscln2
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0                Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1                 Alaska    733375   5.909580838323351%  60.910179640718574%
# 2                Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3               Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4             California  38421464  37.291874687968054%   40.21578881677474%
# 5               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 7            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 8               Delaware    926454    8.82476635514019%   64.63271028037383%
# 9   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 10               Florida  19645772    21.3385426653884%   59.08374880153398%
# 11               Georgia  10006693   8.418242207460397%   54.28630556974962%
# ...

# %%
plt.scatter(dfus_censuscln2.FemalePop, dfus_censuscln2.Income);
plt.show()

# %%
dfus_censuscln3 = dfus_censuscln2.copy()

# %%
dfus_censuscln3.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop', 'MalePop', 'FemalePop'],
#       dtype='object')

# %%
dfus_censuscln3.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income            GenderPop     MalePop  \
# 0  0.03435374149659865%  43296.358603    2341093M_2489527F   2341093.0
# ...

# %%
for i in ['Hispanic', 'White', 'Black', 'Native', 'Asian','Pacific']:
    dfus_censuscln3[i].replace(to_replace="([0-9,\.]+)*\%", value=r"\1", regex=True, inplace=True)

# %%
dfus_censuscln3.head()
# Out:
#         State  TotalPop            Hispanic               White  \
# 0     Alabama   4830620  3.7516156462584975     61.878656462585
# 1      Alaska    733375   5.909580838323351  60.910179640718574
# 2     Arizona   6641928  29.565921052631502  57.120000000000026
# 3    Arkansas   2958208   6.215474452554738   71.13781021897813
# 4  California  38421464  37.291874687968054   40.21578881677474
#
#                 Black               Native               Asian  \
# 0   31.25297619047618   0.4532312925170065  1.0502551020408146
# 1  2.8485029940119775    16.39101796407186   5.450299401197604
# 2  3.8509868421052658     4.35506578947368   2.876578947368419
# 3  18.968759124087573   0.5229197080291965  1.1423357664233578
# 4   5.677396405391911  0.40529206190713685  13.052234148776776
#
#                Pacific        Income            GenderPop     MalePop  \
# 0  0.03435374149659865  43296.358603    2341093M_2489527F   2341093.0
# ...

# %%
dfus_censuscln3.isnull().any()
# Out:
# State        False
# TotalPop     False
# Hispanic     False
# White        False
# Black        False
# Native       False
# Asian        False
# Pacific       True
# Income       False
# GenderPop    False
# MalePop      False
# FemalePop    False
# dtype: bool

# %%
dfus_censuscln3[dfus_censuscln3.isnull().any(axis = 1)]
# Out:
#            State  TotalPop            Hispanic              White  \
# 5       Colorado   5278906   20.78438003220608  69.89557165861504
# 8       Delaware    926454    8.82476635514019  64.63271028037383
# 19        Kansas   2892987  11.644342105263148  75.95828947368425
# 40  North Dakota    721640   2.832682926829267  87.44829268292683
#
#                  Black               Native               Asian Pacific  \
# 5    3.546376811594201   0.5738325281803548   2.661996779388082     NaN
# 8   20.743925233644834  0.25981308411214965  3.2686915887850483     NaN
# 19     6.5678947368421   0.7339473684210529   2.331052631578946     NaN
# 40  1.2843902439024397    5.651219512195119  0.9619512195121945     NaN
#
#           Income          GenderPop    MalePop  FemalePop
# 5   64657.801787  2648667M_2630239F  2648667.0  2630239.0
# 8   61827.976636    448413M_478041F   448413.0   478041.0
# 19  53885.612648  1439862M_1453125F  1439862.0  1453125.0
# ...

# %%
racecols = ['Hispanic', 'White', 'Black', 'Native', 'Asian','Pacific']
dfus_censuscln3[racecols] = dfus_censuscln3[racecols].apply(pd.to_numeric, axis=1)

# %%
dfus_censuscln3[['Hispanic', 'White', 'Black', 'Native', 'Asian','Pacific']].sum(axis = 1)
# Out:
# 0     98.421088
# 1     92.568263
# 2     97.936184
# 3     98.134161
# 4     96.993997
# 5     97.462158
# 7     97.796739
# 8     97.729907
# 9     97.659777
# 10    98.133102
# 11    98.124681
# 13    81.767722
# 14    97.939597
# 15    98.183788
# 16    97.960598
# 17    98.324666
# 19    97.235526
# 20    98.068981
# 21    98.363830
# 22    98.043590
# 23    97.394096
# 25    97.318989
# 26    97.576890
# 27    97.497826
# 28    98.902128
# 29    97.756916
# 31    97.817037
# 32    98.080075
# 33    96.837261
# 34    98.219178
# 35    97.932767
# 37    98.261647
# 38    97.621824
# 39    97.912805
# 40    98.178537
# 41    97.595036
# 43    93.078278
# 44    96.508000
# 45    98.082230
# 46    99.839008
# 47    96.994583
# 49    98.284890
# 50    97.643243
# 51    98.171005
# 52    98.384350
# 53    97.996581
# 55    98.144262
# 56    97.190474
# 57    95.606436
# 58    97.991529
# 59    98.121264
# dtype: float64

# %%
dfus_censuscln3[['Hispanic', 'White', 'Black', 'Native', 'Asian','Pacific']].mean()
# Out:
# Hispanic    12.648577
# White       67.260478
# Black       11.944896
# Native       1.548132
# Asian        3.644623
# Pacific      0.306500
# dtype: float64

# %%
dfus_censuscln4 = dfus_censuscln3.copy()

# %%
dfus_censuscln4.Pacific.fillna(dfus_censuscln4.Pacific.mean(), inplace = True)

# %%
dfus_censuscln4
# Out:
#                    State  TotalPop   Hispanic      White      Black  \
# 0                Alabama   4830620   3.751616  61.878656  31.252976
# 1                 Alaska    733375   5.909581  60.910180   2.848503
# 2                Arizona   6641928  29.565921  57.120000   3.850987
# 3               Arkansas   2958208   6.215474  71.137810  18.968759
# 4             California  38421464  37.291875  40.215789   5.677396
# 5               Colorado   5278906  20.784380  69.895572   3.546377
# 7            Connecticut   3593222  15.604831  67.677053  10.348068
# 8               Delaware    926454   8.824766  64.632710  20.743925
# 9   District of Columbia    647484   9.165922  33.103911  51.776536
# 10               Florida  19645772  21.338543  59.083749  15.165676
# 11               Georgia  10006693   8.418242  54.286306  32.088298
# 13                Hawaii   1406299   9.186709  25.032278   2.052848
# 14                 Idaho   1616547  11.505369  83.136242   0.566779
# ...

# %%
dfus_censuscln4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020C52B9E8B0>,
# ...
#       dtype=object)

# %% [markdown]
# # Part 2

# %%
dfinventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
dfstaten_island = dfinventory.head(10)

# %%
product_request = dfstaten_island.product_description

# %%
dfinventory
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
seed_request = dfinventory[(dfinventory.location == 'Brooklyn')&(dfinventory.product_type == 'seeds')]

# %%
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
dfinventory2 = dfinventory.copy()

# %%
dfinventory2
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
import numpy as np

# %%
dfinventory2['in_stock'] = np.where(dfinventory2.quantity > 0, True, False)

# %%
dfinventory2
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
dfinventory2['total_value'] = dfinventory2.quantity * dfinventory2.price

# %%
dfinventory2
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
combine_lambda = lambda row:'{} - {}'.format(row.product_type, row.product_description)

# %%
dfinventory2['full_description'] = dfinventory2.apply(combine_lambda, axis = 1)

# %%
dfinventory2
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...
